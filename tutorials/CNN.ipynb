# %%
import matplotlib.pyplot as plt
import time

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
# Download training data from open datasets.
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

# %%
batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break
# Out:
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64

# %%
for _ in test_dataloader:
    plt.imshow(_[0][0][0], cmap='Greys')
    plt.show()
    break

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
# device = 'cpu'
print(f"Using {device} device")

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear_relu_stack = nn.Sequential(
            nn.Conv2d(1, 3, 3),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(3, 9, 3),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Flatten(),
            nn.Linear(9 * 5 * 5, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, 10)
        )

    def forward(self, x):
        logits = self.linear_relu_stack(x)
        return logits
        
model = NeuralNetwork().to(device)
# Out:
# Using cuda device

# %%
_ = next(iter(train_dataloader))[0]
print(_.shape)
_ = nn.Conv2d(1, 3, 3)(_)
print(_.shape)
_ = nn.ReLU()(_)
print(_.shape)
_ = nn.MaxPool2d(2, 2)(_)
print(_.shape)
_ = nn.Conv2d(3, 9, 3)(_)
print(_.shape)
_ = nn.ReLU()(_)
print(_.shape)
_ = nn.MaxPool2d(2, 2)(_)
print(_.shape)
_ = nn.Flatten()(_)
print(_.shape)
_ = nn.Linear(9 * 5 * 5, 64)(_)
print(_.shape)
_ = nn.ReLU()(_)
print(_.shape)
_ = nn.Linear(64, 64)(_)
print(_.shape)
_ = nn.ReLU()(_)
print(_.shape)
_ = nn.Linear(64, 10)(_)
print(_.shape)
# Out:
# torch.Size([64, 1, 28, 28])
# torch.Size([64, 3, 26, 26])
# torch.Size([64, 3, 26, 26])
# torch.Size([64, 3, 13, 13])
# torch.Size([64, 9, 11, 11])
# torch.Size([64, 9, 11, 11])
# torch.Size([64, 9, 5, 5])
# torch.Size([64, 225])
# torch.Size([64, 64])
# torch.Size([64, 64])
# torch.Size([64, 64])
# torch.Size([64, 64])
# torch.Size([64, 10])

# %%
try:
    model = NeuralNetwork().to(device)
    model.load_state_dict(torch.load("model.CNN.pth"))
    print('loaded model')
except:
    model = NeuralNetwork().to(device)
    print("couldn't load model")
# Out:
# loaded model

# %%
total_params = 0
for params in model.parameters():
    total_params += params.nelement()
print('Total parameters:', total_params)
# Out:
# Total parameters: 19556

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3, momentum=0.9)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
epochs = 5
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.281238  [    0/60000]
# loss: 0.402449  [ 6400/60000]
# loss: 0.281351  [12800/60000]
# loss: 0.497879  [19200/60000]
# loss: 0.404824  [25600/60000]
# loss: 0.409571  [32000/60000]
# loss: 0.366401  [38400/60000]
# loss: 0.567236  [44800/60000]
# loss: 0.558456  [51200/60000]
# loss: 0.447039  [57600/60000]
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.436534
#
# Epoch 2
# -------------------------------
# loss: 0.272855  [    0/60000]
# loss: 0.398212  [ 6400/60000]
# loss: 0.276283  [12800/60000]
# loss: 0.488834  [19200/60000]
# loss: 0.401503  [25600/60000]
# loss: 0.406350  [32000/60000]
# loss: 0.369790  [38400/60000]
# loss: 0.559535  [44800/60000]
# loss: 0.552768  [51200/60000]
# loss: 0.447321  [57600/60000]
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.430665
#
# Epoch 3
# -------------------------------
# loss: 0.261791  [    0/60000]
# loss: 0.398213  [ 6400/60000]
# loss: 0.268158  [12800/60000]
# loss: 0.483564  [19200/60000]
# loss: 0.408226  [25600/60000]
# loss: 0.407480  [32000/60000]
# loss: 0.366716  [38400/60000]
# loss: 0.564025  [44800/60000]
# loss: 0.542420  [51200/60000]
# loss: 0.447184  [57600/60000]
# Test Error:
#  Accuracy: 84.5%, Avg loss: 0.429464
#
# Epoch 4
# -------------------------------
# loss: 0.262493  [    0/60000]
# loss: 0.394441  [ 6400/60000]
# loss: 0.260891  [12800/60000]
# loss: 0.482301  [19200/60000]
# loss: 0.402271  [25600/60000]
# loss: 0.400769  [32000/60000]
# loss: 0.367972  [38400/60000]
# loss: 0.564520  [44800/60000]
# loss: 0.537610  [51200/60000]
# loss: 0.451199  [57600/60000]
# Test Error:
#  Accuracy: 84.6%, Avg loss: 0.426982
#
# Epoch 5
# -------------------------------
# loss: 0.258499  [    0/60000]
# loss: 0.392831  [ 6400/60000]
# loss: 0.257341  [12800/60000]
# loss: 0.475820  [19200/60000]
# loss: 0.403139  [25600/60000]
# loss: 0.398018  [32000/60000]
# loss: 0.368944  [38400/60000]
# loss: 0.562669  [44800/60000]
# loss: 0.536160  [51200/60000]
# loss: 0.447050  [57600/60000]
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.419863
#
# Done!

# %%
torch.save(model.state_dict(), "model.CNN.pth")
print("Saved PyTorch Model State to model.CNN.pth")
# Out:
# Saved PyTorch Model State to CNN.pt

# %%
classes = [
    "T-shirt/top",
    "Trouser",
    "Pullover",
    "Dress",
    "Coat",
    "Sandal",
    "Shirt",
    "Sneaker",
    "Bag",
    "Ankle boot",
]

model.eval()
x, y = next(iter(test_dataloader))
with torch.no_grad():
    pred = model(x.to(device))
    predicted, actual = classes[pred[0].argmax(0)], classes[y[0]]
    print(f'Predicted: "{predicted}", Actual: "{actual}"')
# Out:
# Predicted: "Ankle boot", Actual: "Ankle boot"

# %%
model.eval()
num_show = 10
with torch.no_grad():
    for x, y in test_dataloader:
        pred = model(x.to(device))
        for i in range(len(pred)):
            predicted, actual = classes[pred[i].argmax(0)], classes[y[i]]
            if predicted != actual:
                print(f'Predicted: "{predicted}", Actual: "{actual}"')
                plt.imshow(x[i][0], cmap='Greys')
                plt.show()
                num_show -= 1
            if num_show < 0:
                break
        if num_show < 0:
            break
# Out:
# Predicted: "Shirt", Actual: "Pullover"
# Predicted: "Sneaker", Actual: "Sandal"
# Predicted: "Sandal", Actual: "Ankle boot"
# Predicted: "Pullover", Actual: "Coat"
# Predicted: "T-shirt/top", Actual: "Shirt"
# Predicted: "Coat", Actual: "Shirt"
# Predicted: "Coat", Actual: "Pullover"
# Predicted: "Shirt", Actual: "Pullover"
# Predicted: "Pullover", Actual: "Coat"
# Predicted: "Shirt", Actual: "Coat"
# Predicted: "Dress", Actual: "Pullover"
